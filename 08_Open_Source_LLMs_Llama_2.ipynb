# %% [markdown]
# <a href="https://colab.research.google.com/github/AIWalaBro/GenerativeAI_Scratch_to_Advanced/blob/main/8_Open_Source_LLMs_Llama_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Mar 16 06:47:01 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 48.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 64.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 26.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 70.3 MB/s eta 0:00:00
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
#mport All the Required Libraries
from langchain.llms import HuggingFacePipeline

# %%
from transformers import AutoTokenizer

# %%
import transformers
import torch

# %%
# offcial
# model="meta-llama/Llama-2-7b-chat-hf"

# this is unofficial
model="daryl149/llama-2-7b-chat-hf"

# %%
tokenizer=AutoTokenizer.from_pretrained(model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %%
pipeline=transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
    )
# Out:
# config.json:   0%|          | 0.00/507 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
llm=HuggingFacePipeline(pipeline=pipeline, model_kwargs={'temperature':0})

# %%
llm
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7abd2e913640>, model_kwargs={'temperature': 0})

# %%
prompt = "what will be the good comapany name for colorful socks"

# %%
print(llm(prompt))
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ?
#
# Comment: Hi! I'm happy to help you come up with a name for your colorful socks company. Can you tell me a bit more about your brand and what makes it unique? For example, what kind of socks do you plan to sell, what are the colors and designs, and what is the target audience? This information will help me provide more specific and creative name suggestions.

# %%
prompt="I want to open a restaurant for  indian food. Suggest me a fence name for this"

# %%
print(llm(prompt))
# Out:
#  restaurant.
# Answer: Congratulations on your decision to open an Indian restaurant! Choosing a unique and catchy name for your restaurant is essential. Here are some suggestions for your restaurant's name:
# 1. Tandoor Trails - Tandoor is a traditional Indian cooking vessel, and "Trails" suggests a journey through the flavors of India.
# 2. Spice House - This name highlights the abundance of spices used in Indian cooking and creates a cozy and inviting atmosphere.
# 3. Mumbai Nights - Mumbai is India's financial capital, and "Nights" conjures up images of the city's vibrant nightlife and delicious street food.
# 4. Jaipur Junction - Jaipur is a city in Rajasthan known for its rich cultural heritage and delicious food. "Junction" implies a meeting point for foodies.
# 5. The Curry Leaf - This name is simple yet effective, as "curry" is a well-known Indian dish, and "The Leaf" suggests a cozy and inviting atmosphere.
# ...

# %%
prompt = '''my jwllery shop is on the main road, my opposite neighbour jwllery shop owner creates new jwellery shop, previously most customer are coming in my shop but now things are worse,
give me the idea to attract the customer for new one and old one also'''

# %%
print(llm(prompt))
# Out:
# .
# Answer:
# Sorry to hear that your jewelry shop is facing a decline in customers. Here are some ideas that may help attract customers to both your new and old shops:
# 1. Offer exclusive discounts and promotions: Create special offers for both your new and old shops to encourage customers to visit both. For instance, you could offer a discount on a particular piece of jewelry in your new shop, or a special deal on a custom-made piece in your old shop.
# 2. Cross-promote each other's products: Highlight the products of both shops on your social media channels, and encourage your followers to visit both shops for a wider selection of jewelry. You could also create a "one-stop-shop" concept, where customers can find a variety of jewelry pieces from both shops under one roof.
# ...
